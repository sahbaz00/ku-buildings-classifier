# %%
# import os
# import cv2

# BASE_DIR = os.getcwd() # it will be used in whole processes to easily access folders
# VIDEOS_DIR = os.path.join(BASE_DIR, "videos")
# FRAME_SKIP = 15 

# for class_name in os.listdir(VIDEOS_DIR):
#     class_path = os.path.join(VIDEOS_DIR, class_name)
    
#     if not os.path.isdir(class_path):
#         continue
        
#     for video_file in os.listdir(class_path):
#         if not video_file.lower().endswith(('.mp4', '.mov', '.avi')):
#             continue
            
#         video_path = os.path.join(class_path, video_file)
#         video_name = os.path.splitext(video_file)[0] 
#         output_folder = os.path.join(class_path, video_name)
#         os.makedirs(output_folder, exist_ok=True)
        
#         print(f"Processing: {class_name}/{video_file} -> extracting to /{video_name}/")
#         cap = cv2.VideoCapture(video_path)
        
#         frame_counter = 0
#         saved_counter = 0
        
#         while True:
#             success, frame = cap.read()
#             if not success:
#                 break
#             if frame_counter % FRAME_SKIP == 0:
#                 frame_filename = f"frame_{saved_counter}.jpg"
#                 save_path = os.path.join(output_folder, frame_filename)
                
#                 cv2.imwrite(save_path, frame)
#                 saved_counter += 1
                
#             frame_counter += 1
            
#         cap.release()
#         print(f"  -> Extracted {saved_counter} frames.\n")

# print("Video frame extraction complete!")

# %%
import os
import cv2

BASE_DIR = os.getcwd() # it will be used in whole processes to easily access folders
VIDEOS_DIR = os.path.join(BASE_DIR, "videos")

FRAME_SKIP = 15 # it will take 2 photos a second

for class_name in os.listdir(VIDEOS_DIR):
    class_path = os.path.join(VIDEOS_DIR, class_name)
    
    if not os.path.isdir(class_path):
        continue
        
    for video_file in os.listdir(class_path):
        if not video_file.lower().endswith(('.mp4', '.mov', '.avi')):
            continue
            
        video_path = os.path.join(class_path, video_file)
        video_name = os.path.splitext(video_file)[0] 
        
        # Everything will be saved directly into the main class_path
        print(f"Processing: {class_name}/{video_file} -> extracting to /{class_name}/")
        cap = cv2.VideoCapture(video_path)
        
        frame_counter = 0
        saved_counter = 0
        
        while True:
            success, frame = cap.read()
            if not success:
                break
                
            if frame_counter % FRAME_SKIP == 0:
                # to prevent overwriting we add file_name
                frame_filename = f"{video_name}_frame_{saved_counter}.jpg"
                save_path = os.path.join(class_path, frame_filename)
                
                cv2.imwrite(save_path, frame)
                saved_counter += 1
                
            frame_counter += 1
            
        cap.release()
        print(f"  -> Extracted {saved_counter} frames from {video_file}.\n")

print("Video frame extraction complete!")
# Out:
# Scanning C:\Users\Shahbaz\Desktop\dl\videos for video files...
#
# Processing: church/church1.mp4 -> extracting to /church/
#   -> Extracted 25 frames from church1.mp4.
#
# Processing: church/church2.mp4 -> extracting to /church/
#   -> Extracted 42 frames from church2.mp4.
#
# Processing: church/church3.mp4 -> extracting to /church/
#   -> Extracted 48 frames from church3.mp4.
#
# Processing: church/church4.mp4 -> extracting to /church/
#   -> Extracted 85 frames from church4.mp4.
#
# Processing: georgianum/georgianum1.mp4 -> extracting to /georgianum/
#   -> Extracted 46 frames from georgianum1.mp4.
#
# Processing: georgianum/georgianum2.mp4 -> extracting to /georgianum/
#   -> Extracted 48 frames from georgianum2.mp4.
#
# Processing: georgianum/georgianum3.mp4 -> extracting to /georgianum/
#   -> Extracted 34 frames from georgianum3.mp4.
#
# Processing: georgianum/georgianum4.mp4 -> extracting to /georgianum/
#   -> Extracted 33 frames from georgianum4.mp4.
#
# Processing: georgianum/georgianum5.mp4 -> extracting to /georgianum/
#   -> Extracted 41 frames from georgianum5.mp4.
#
# Processing: hauptbau/hauptbau1.mp4 -> extracting to /hauptbau/
#   -> Extracted 72 frames from hauptbau1.mp4.
#
# Processing: kreuztor/kreuztor1.mp4 -> extracting to /kreuztor/
#   -> Extracted 11 frames from kreuztor1.mp4.
#
# Processing: kreuztor/kreuztor2.mp4 -> extracting to /kreuztor/
#   -> Extracted 28 frames from kreuztor2.mp4.
#
# Processing: ku/ku.mp4 -> extracting to /ku/
#   -> Extracted 136 frames from ku.mp4.
#
# Processing: ku/ku1.mp4 -> extracting to /ku/
#   -> Extracted 36 frames from ku1.mp4.
#
# Processing: pink/pink1.mp4 -> extracting to /pink/
#   -> Extracted 65 frames from pink1.mp4.
#
# Processing: pink/pink2.mp4 -> extracting to /pink/
#   -> Extracted 53 frames from pink2.mp4.
#
# Processing: pink/pink3.mp4 -> extracting to /pink/
#   -> Extracted 65 frames from pink3.mp4.
#
# Processing: wfi/wfi1.mp4 -> extracting to /wfi/
#   -> Extracted 70 frames from wfi1.mp4.
#
# Video frame extraction complete!
