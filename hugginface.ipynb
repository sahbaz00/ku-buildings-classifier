# %%
import tensorflow as tf

model = tf.keras.models.load_model("Phase3.keras")

# %%
model.export("Phase3_savedmodel")
# Out:
# INFO:tensorflow:Assets written to: Phase3_savedmodel\assets
# INFO:tensorflow:Assets written to: Phase3_savedmodel\assets
# Saved artifact at 'Phase3_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 168, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 9), dtype=tf.float32, name=None)
# Captures:
#   2835201002304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201281184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201289104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201294032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201655200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2835201655904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
